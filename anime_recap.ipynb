# %%
from dotenv import load_dotenv
from openai import OpenAI
from elevenlabs.client import AsyncElevenLabs
import asyncio
import json
import os
import argparse
import concurrent.futures

from manga_extraction import extract_all_pages_as_images, save_important_pages, split_volume_into_parts, save_all_pages
from vision_analysis import analyze_images_with_gpt4_vision, detect_important_pages, VISION_PRICE_PER_TOKEN 
from prompts import DRAMATIC_PROMPT, BASIC_PROMPT, BASIC_PROMPT_WITH_CONTEXT,  BASIC_INSTRUCTIONS, KEY_PAGE_IDENTIFICATION_INSTRUCTIONS
from citation_processing import extract_text_and_citations, extract_script
from movie_director import make_movie
from panel_extractor.panel_extractor import PanelExtractor
load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
volume_number = 10
manga = "naruto"

# %%
# Initialize OpenAI client with API key
client = OpenAI()
# get elevenlabs api key from dotenv
narration_client = AsyncElevenLabs(api_key=os.getenv("ELEVENLABS_API_KEY"))

print("Extracting all pages from the volume...")
volume_scaled_and_unscaled = extract_all_pages_as_images(f"{manga}/v{volume_number}/v{volume_number}.pdf")
volume = volume_scaled_and_unscaled["scaled"]
print("Total pages in volume:", len(volume))
# Out:
# Extracting all pages from the volume...
# Total pages in volume: 177

# %%
dir = save_all_pages(volume_scaled_and_unscaled["full"], manga, volume_number)

# %%
panel_extractor = PanelExtractor(keep_text=True, min_pct_panel=2, max_pct_panel=90)
panel_extractor.extract(dir)
# Out:
# Load text detector ... Done!
# Loading images ... Done!
# Removing images with paper texture: 100%|██████████| 177/177 [00:01<00:00, 93.38it/s]
# extracting panels: 154it [00:02, 70.58it/s]

# %%
profile_reference = extract_all_pages_as_images(f"{manga}/profile-reference.pdf")["scaled"]
chapter_reference = extract_all_pages_as_images(f"{manga}/chapter-reference.pdf")["scaled"]

profile_pages = []
chapter_pages = [] 

important_page_tokens = 0

batch_size = 20

print("Identifying important pages in the volume...")
# Function to wrap the detect_important_pages call
def process_batch(start_idx, pages):
    response = detect_important_pages(profile_reference, chapter_reference, pages, client,
        KEY_PAGE_IDENTIFICATION_INSTRUCTIONS, KEY_PAGE_IDENTIFICATION_INSTRUCTIONS)
    return start_idx, response

# Using ThreadPoolExecutor to parallelize API calls
with concurrent.futures.ThreadPoolExecutor() as executor:
    futures = []
    for i in range(0, len(volume), batch_size):
        pages = volume[i:i+batch_size]
        futures.append(executor.submit(process_batch, i, pages))

    for future in concurrent.futures.as_completed(futures):
        start_idx, response = future.result()
        end_index = start_idx + batch_size - 1
        print(f"Processing pages {start_idx} to {min(end_index, len(volume)-1)}")
        
        ip = response["parsed_response"]
        print(json.dumps(ip, indent=2))
        for page in ip:
            if page["type"] == "profile":
                profile_pages.append(page["image_index"] + start_idx)
            elif page["type"] == "chapter":
                chapter_pages.append(page["image_index"] + start_idx)

        important_page_tokens += response["total_tokens"]

profile_pages.sort()
chapter_pages.sort()

print("Total tokens to extract profiles and chapters:", important_page_tokens)
print("\n__________\n")
print("Profile pages:", profile_pages)
print("Chapter pages:", chapter_pages)
# Out:
# Identifying important pages in the volume...
# Using GPT as a backup to format JSON object...
# Processing pages 60 to 79
# [
#   {
#     "image_index": 5,
#     "type": "chapter"
#   }
# ]
# Using GPT as a backup to format JSON object...
# Using GPT as a backup to format JSON object...
# Using GPT as a backup to format JSON object...
# Processing pages 160 to 176
# [
#   {
#     "image_index": 15,
#     "type": "chapter"
#   }
# ]
# Processing pages 80 to 99
# [
#   {
#     "image_index": 3,
#     "type": "chapter"
#   }
# ]
# Processing pages 100 to 119
# [
#   {
#     "image_index": 1,
#     "type": "chapter"
#   },
#   {
#     "image_index": 19,
#     "type": "chapter"
#   }
# ]
# Using GPT as a backup to format JSON object...
# Processing pages 40 to 59
# [
#   {
#     "image_index": 5,
#     "type": "chapter"
#   }
# ]
# Using GPT as a backup to format JSON object...
# Using GPT as a backup to format JSON object...
# Processing pages 140 to 159
# [
#   {
#     "image_index": 18,
#     "type": "chapter"
#   }
# ]
# Using GPT as a backup to format JSON object...
# Processing pages 120 to 139
# [
#   {
#     "image_index": 18,
#     "type": "chapter"
#   }
# ]
# Using GPT as a backup to format JSON object...
# Processing pages 20 to 39
# [
#   {
#     "image_index": 7,
#     "type": "chapter"
#   }
# ]
# Processing pages 0 to 19
# [
#   {
#     "image_index": 4,
#     "type": "profile"
#   },
#   {
#     "image_index": 5,
#     "type": "profile"
#   },
#   {
#     "image_index": 7,
#     "type": "chapter"
#   }
# ]
# Total tokens to extract profiles and chapters: 31011
#
# __________
#
# Profile pages: [4, 5]
# Chapter pages: [7, 27, 45, 65, 83, 101, 119, 138, 158, 175]

# %%
print(f"{len(volume)}")
print("\n__________\n")
print("Saving important pages to disk for QA...")
save_important_pages(volume, profile_pages, chapter_pages, manga, volume_number)
# Out:
# 177
#
# __________
#
# Saving important pages to disk for QA...

# %%
character_profiles = [volume[i] for i in profile_pages]    
jobs = split_volume_into_parts(volume, chapter_pages, 3)

# Summarize the images in the first job
response = analyze_images_with_gpt4_vision(character_profiles, jobs[0], client, BASIC_PROMPT, BASIC_INSTRUCTIONS)
recap = response.choices[0].message.content
tokens = response.usage.total_tokens
movie_script = extract_text_and_citations(response.choices[0].message.content, jobs[0])

print("\n\n\n_____________\n\n\n")
print(response.choices[0].message.content)

# iterate thrugh the rest of the jobs while adding context from previous ones
for job in jobs[1:]:
    response = analyze_images_with_gpt4_vision(character_profiles, job, client, recap + "\n-----\n" + BASIC_PROMPT_WITH_CONTEXT, BASIC_INSTRUCTIONS)
    recap = recap + "\n\n" + response.choices[0].message.content
    tokens += response.usage.total_tokens
    print("\n\n\n_____________\n\n\n")
    print(response.choices[0].message.content)
    movie_script = movie_script + extract_text_and_citations(response.choices[0].message.content, job)

print("\n\n\n_____________\n\n\n")
print("\n\n\n_____________\n\n\n")
print("\n\n\n_____________\n\n\n")

narration_script = extract_script(movie_script)
print(narration_script)
print("\n___________\n")

ELEVENLABS_PRICE_PER_CHARACTER = 0.0003
print("Tokens for extracting profiles and chapters:", important_page_tokens, " | ", "${:,.4f}".format(VISION_PRICE_PER_TOKEN * important_page_tokens))
print("Tokens for summarization:", tokens,  " | ", "${:,.4f}".format(VISION_PRICE_PER_TOKEN * tokens))
print("Total GPT tokens:", important_page_tokens + tokens,  " | ", "${:,.4f}".format(VISION_PRICE_PER_TOKEN * (tokens+important_page_tokens)))
print("Total elevenlabs characters:", len(narration_script), " | ", "${:,.4f}".format(ELEVENLABS_PRICE_PER_CHARACTER * (len(narration_script))))
print("GRAND TOTAL COST"," | ", "${:,.4f}".format(VISION_PRICE_PER_TOKEN * (tokens+important_page_tokens) + ELEVENLABS_PRICE_PER_CHARACTER * (len(narration_script))))
# Out:
# 7->65
# 66->138
# 139->end (177)
#
#
#
# _____________
#
#
#
# Amidst the fervor of the Chunin Exams, a clash of ideologies and techniques unfolds as Rock Lee, a prodigy of sheer effort, faces off against Gaara, a natural talent nurtured by the sand. The young ninja Lee, unfazed by Gaara's intimidating presence, launches himself into battle with his characteristic vigor. His initial salvo is thwarted by Gaara's sand, a defense seemingly unconquerable. Lee's mentor, Might Guy, watches with a solemn intensity, aware of Lee's limitations and strengths[^3][^4][^5].
#
# Lee's unorthodox training and reliance on physical prowess impress onlookers[^8][^9]; he battles without the aid of ninjutsu or genjutsu, confounding the usual expectations of a ninja's skill set[^10]. With his spirit unyielding, Lee reveals his first trump card under Might Guy's approval—a set of weighted ankle wraps. Casting them aside, his true speed is unleashed—a blur too swift for the naked eye[^14][^15][^16]. The arena shakes, and Lee lands a succession of blows against Gaara, who reels from the unforeseen assault[^17][^18].
#
# The mighty Gaara, however, is undeterred, his sand armor absorbing the brunt of Lee's ferocity[^24]. The crowd is breathless as the fabric of Gaara's ultimate defense begins to unravel, his invincibility questioned[^28][^29][^30]. The tide turns when Lee, with an adamant commitment to his ethos of hard work, prepares his forbidden technique, the Front Lotus[^34][^35]. Gaara, ensnared within Lee's whirlwind, experiences the brunt of the attack[^39].
#
# This spectacle stirs the hearts of those who witness it, as a seemingly hopeless genin defies the odds through sheer determination[^51][^52][^53]. Echoing through the battleground are the thoughts of Lee's immense effort, his relentless training, and his steadfast belief in hard work over natural ability[^57][^58].
#
# In an inspiring culmination, as Lee stands poised, ready to push his limits further still, Might Guy reflects with pride on his pupil's grit—the embodiment of hard work's true genius[^60]. The final page remains silent, yet it speaks volumes, leaving the outcome of Lee's ambition and sacrifice lingering in the whispers of sand[^63].
#
#
#
# _____________
#
#
#
# As Rock Lee's determination rages, he decides to take a drastic step. Despite Might Guy's initial hesitation, he gives Lee permission to use the forbidden technique: "The Reverse Lotus!"[^8]. Guy reflects on the dangers of opening the Inner Gates, weighing the potential cost to Lee's life[^9][^10]. Lee's commitment to his shinobi path is unwaivering, unlocking the first gate, "Gate of Opening," with a fierce cry[^11].
#
# Gaara, however, meets Lee's increased power with his unyielding sand defense[^16]. As Lee attacks with blinding speed, a cloud of sand obscures the outcome[^17]. Suddenly, the arena trembles; Lee's Reverse Lotus lands with devastating force, shattering the ground beneath them[^18]. The crowd watches in awe as Lee and Gaara vanish from sight^[19], and with a bone-shattering crash, Gaara reemerges from a pile of rubble, seemingly unscathed[^21].
#
# The sands of the arena whisper with the tension of the fight, as even Neji and Sasuke acknowledge the intense display of strength^[22]. Lee, with all his might unlocked by the Fifth Gate, announces, "This is the end!"[^23]. The ferocity of his impact seems enough to seal Gaara's fate[^24], but in a harrowing twist, Gaara's ultimate defense, the "Coffin of Crushing Sand," ensnares Lee, the pressure threatening to crush him^[25].
#
# The battle reaches its climax when Gaara's sand closes around Lee, binding him in a deathly grip[^28]. As Lee's consciousness fades, the proctor calls the match to avoid a tragic end, declaring Gaara the winner[^29]. Might Guy rushes to Lee's side, cradling his injured pupil, his eyes reflecting the sorrow of a mentor witnessing the toll of a pupil's sacrifice[^30].
#
# In the aftermath, the arena is filled with mixed emotions; the respect for Lee is palpable, his courage and dedication having left an indelible mark on all present[^32]. Naruto grapples with the harsh realities of the ninja world, touched by Lee's resolve[^33]. As the dust settles, Guy carries Lee away, a silent promise hanging between them—a ninja's path is never without risk, and despite the outcome, Lee's spirit remains unbroken[^35].
#
# As attention shifts to the next match, Choji faces Dosu in what would seem an incongruous matchup. Choji employs an unusual strategy using sound against Dosu—a sensory ninja—but ultimately, Dosu's skill prevails[^38].
#
# The final match is between Shikamaru and Temari. The lazy genius, Shikamaru, weaves a ploy to capture Temari, but in a surprising twist, he willingly surrenders despite having the upper hand, deeming the effort too taxing[^39]. With this, the preliminaries conclude, and a one-month interval begins as the competitors prepare for the finals[^40]. The air is heavy with anticipation and intrigue, as dark plans unfurl away from the public eye, setting the stage for events yet to unfold[^41].
#
#
#
# _____________
#
#
#
# In the shadows of the Chunin Exam aftermath, Kakashi is confronted by Kabuto, a spy with uncertain loyalty. "What are you?" Kakashi asks. "A medical-nin, an instructor, a fellow ninja... or are you a spy... for someone else?" As Kabuto deflects with evasive comments, tension coils in the air[^2][^3]. Kakashi warns Kabuto, "You shouldn't mock your superiors," but Kabuto merely retorts, showcasing his adept evasion skills as Kakashi strikes—a clear demonstration of his formidable capabilities[^4][^5].
#
# Meanwhile, the ninja assemble to learn their fate. A lottery determines the match-ups for the next round, but all eyes are set on one particular bout. "So Uchiha Sasuke will be... Naruto's opponent," one announces while perusing the tournament bracket[^9][^10][^11]. Emotions churn among the competitors; the confrontations ahead promise to be explosive.
#
# Naruto braces for the intense training needed to face Sasuke, rushing to find Kakashi only to be intercepted by Ebisu, the self-proclaimed "Elite Teacher." "You're going to teach me?" Naruto asks incredulously. Despite his initial disappointment, Naruto agrees[^17][^18], finding out rather unceremoniously that their training is to learn control over chakra. Ebisu provides meticulous explanations: "Chakra is the essential energy necessary for ninjutsu and genjutsu," he drones on as Naruto listens with half an ear[^22].
#
# Their first task is walking on water, a tedious exercise of chakra control. Ebisu instructs, "In order to learn how to control your chakra, you must attempt to stay above water," while Naruto energetically dives into the challenge[^26]. Yet, Naruto's enthusiasm quickly turns to frustration as he struggles, the boiling hot water scalding his feet with every misstep[^29][^30].
#
# Just as Naruto grapples with the basics, a perverted yet powerful presence interrupts. Jiraiya, one of the Legendary Sannin, appears, and upon dispelling Ebisu's objections with a swift flick, he self-introduces with a lecherous grin. "The Gallant Jiraiya... at your service," he declares[^34][^35]. Naruto finds himself under the tutelage of this unlikely mentor, his training taking an unexpected turn. And with Jiraiya's guidance, an extraordinary power stirs within Naruto; a gigantic toad materializes, hinting at the immense abilities that lie dormant within him[^36]. As the training intensifies, the stage is set for a dramatic shift in Naruto's journey[^38].
#
#
#
# _____________
#
#
#
#
#
#
# _____________
#
#
#
#
#
#
# _____________
#
#
#
# Amidst the fervor of the Chunin Exams, a clash of ideologies and techniques unfolds as Rock Lee, a prodigy of sheer effort, faces off against Gaara, a natural talent nurtured by the sand. The young ninja Lee, unfazed by Gaara's intimidating presence, launches himself into battle with his characteristic vigor. His initial salvo is thwarted by Gaara's sand, a defense seemingly unconquerable. Lee's mentor, Might Guy, watches with a solemn intensity, aware of Lee's limitations and strengths.Lee's unorthodox training and reliance on physical prowess impress onlookers; he battles without the aid of ninjutsu or genjutsu, confounding the usual expectations of a ninja's skill set.With his spirit unyielding, Lee reveals his first trump card under Might Guy's approval—a set of weighted ankle wraps. Casting them aside, his true speed is unleashed—a blur too swift for the naked eye.The arena shakes, and Lee lands a succession of blows against Gaara, who reels from the unforeseen assault.The mighty Gaara, however, is undeterred, his sand armor absorbing the brunt of Lee's ferocity.The crowd is breathless as the fabric of Gaara's ultimate defense begins to unravel, his invincibility questioned.The tide turns when Lee, with an adamant commitment to his ethos of hard work, prepares his forbidden technique, the Front Lotus.Gaara, ensnared within Lee's whirlwind, experiences the brunt of the attack.This spectacle stirs the hearts of those who witness it, as a seemingly hopeless genin defies the odds through sheer determination.Echoing through the battleground are the thoughts of Lee's immense effort, his relentless training, and his steadfast belief in hard work over natural ability.In an inspiring culmination, as Lee stands poised, ready to push his limits further still, Might Guy reflects with pride on his pupil's grit—the embodiment of hard work's true genius. The final page remains silent, yet it speaks volumes, leaving the outcome of Lee's ambition and sacrifice lingering in the whispers of sand.The final page remains silent, yet it speaks volumes, leaving the outcome of Lee's ambition and sacrifice lingering in the whispers of sand.As Rock Lee's determination rages, he decides to take a drastic step. Despite Might Guy's initial hesitation, he gives Lee permission to use the forbidden technique: "The Reverse Lotus!".Guy reflects on the dangers of opening the Inner Gates, weighing the potential cost to Lee's life.Lee's commitment to his shinobi path is unwaivering, unlocking the first gate, "Gate of Opening," with a fierce cry.Gaara, however, meets Lee's increased power with his unyielding sand defense.As Lee attacks with blinding speed, a cloud of sand obscures the outcome.Suddenly, the arena trembles; Lee's Reverse Lotus lands with devastating force, shattering the ground beneath them.The crowd watches in awe as Lee and Gaara vanish from sight, and with a bone-shattering crash, Gaara reemerges from a pile of rubble, seemingly unscathed.The sands of the arena whisper with the tension of the fight, as even Neji and Sasuke acknowledge the intense display of strength.Lee, with all his might unlocked by the Fifth Gate, announces, "This is the end!".The ferocity of his impact seems enough to seal Gaara's fate, but in a harrowing twist, Gaara's ultimate defense, the "Coffin of Crushing Sand," ensnares Lee, the pressure threatening to crush him.The battle reaches its climax when Gaara's sand closes around Lee, binding him in a deathly grip.As Lee's consciousness fades, the proctor calls the match to avoid a tragic end, declaring Gaara the winner.Might Guy rushes to Lee's side, cradling his injured pupil, his eyes reflecting the sorrow of a mentor witnessing the toll of a pupil's sacrifice.In the aftermath, the arena is filled with mixed emotions; the respect for Lee is palpable, his courage and dedication having left an indelible mark on all present.Naruto grapples with the harsh realities of the ninja world, touched by Lee's resolve.As the dust s ...
#
# Naruto braces for the intense training needed to face Sasuke, rushing to find Kakashi only to be intercepted by Ebisu, the self-proclaimed "Elite Teacher." "You're going to teach me?" Naruto asks incredulously. Despite his initial disappointment, Naruto agrees, finding out rather unceremoniously that their training is to learn control over chakra. Ebisu provides meticulous explanations: "Chakra is the essential energy necessary for ninjutsu and genjutsu," he drones on as Naruto listens with half an ear.Their first task is walking on water, a tedious exercise of chakra control. Ebisu instructs, "In order to learn how to control your chakra, you must attempt to stay above water," while Naruto energetically dives into the challenge.Yet, Naruto's enthusiasm quickly turns to frustration as he struggles, the boiling hot water scalding his feet with every misstep.Just as Naruto grapples with the basics, a perverted yet powerful presence interrupts. Jiraiya, one of the Legendary Sannin, appears, and upon dispelling Ebisu's objections with a swift flick, he self-introduces with a lecherous grin. "The Gallant Jiraiya... at your service," he declares.Naruto finds himself under the tutelage of this unlikely mentor, his training taking an unexpected turn. And with Jiraiya's guidance, an extraordinary power stirs within Naruto; a gigantic toad materializes, hinting at the immense abilities that lie dormant within him.As the training intensifies, the stage is set for a dramatic shift in Naruto's journey.
#
# ___________
#
# Tokens for extracting profiles and chapters: 31011  |  $0.3101
# Tokens for summarization: 19951  |  $0.1995
# Total GPT tokens: 50962  |  $0.5096
# Total elevenlabs characters: 7189  |  $2.1567
# GRAND TOTAL COST  |  $2.6663

# %%
await make_movie(movie_script, manga, volume_number, narration_client)
# Out:
# Narrating movie script...
# got bytes: 67291
# got bytes: 88189
# got bytes: 112013
# got bytes: 202710
# got bytes: 84427
# got bytes: 104071
# got bytes: 76486
# got bytes: 130821
# got bytes: 111177
# got bytes: 136672
# got bytes: 126223
# got bytes: 519941
# got bytes: 91115
# got bytes: 178050
# got bytes: 101564
# got bytes: 68127
# got bytes: 70635
# got bytes: 312633
# got bytes: 114102
# got bytes: 56424
# got bytes: 90697
# got bytes: 68963
# got bytes: 119536
# got bytes: 56424
# got bytes: 122462
# got bytes: 85263
# got bytes: 84009
# got bytes: 128313
# got bytes: 82337
# got bytes: 165511
# got bytes: 191425
# got bytes: 95712
# got bytes: 232385
# got bytes: 132911
# got bytes: 213995
# got bytes: 204382
# got bytes: 287973
# got bytes: 334367
# got bytes: 354847
# got bytes: 301348
# got bytes: 247849
# got bytes: 131239
# got bytes: 80666
# got bytes: 318484
# got bytes: 285048
# Editing movie together...
# Number of images in segment 0: 1
# Audio duration: 32.5
# Number of images in segment 1: 3
# Audio duration: 4.21
# Number of images in segment 2: 2
# Audio duration: 7.0
# Number of images in segment 3: 1
# Audio duration: 12.67
# Number of images in segment 4: 3
# Audio duration: 5.51
# Number of images in segment 5: 2
# Audio duration: 5.28
# Number of images in segment 6: 1
# Audio duration: 6.5
# Number of images in segment 7: 3
# Audio duration: 8.18
# Number of images in segment 8: 2
# Audio duration: 4.78
# Number of images in segment 9: 1
# Audio duration: 6.95
# Number of images in segment 10: 3
# Audio duration: 8.54
# Number of images in segment 11: 1
# Audio duration: 19.54
# Number of images in segment 12: 0
# Number of images in segment 13: 1
# Audio duration: 11.13
# Number of images in segment 14: 1
# Audio duration: 5.69
# Number of images in segment 15: 2
# Audio duration: 6.35
# Number of images in segment 16: 1
# Audio duration: 4.26
# Number of images in segment 17: 1
# Audio duration: 4.41
# Number of images in segment 18: 1
# Audio duration: 7.13
# Number of images in segment 19: 1
# Audio duration: 3.53
# Number of images in segment 20: 1
# Audio duration: 5.67
# Number of images in segment 21: 1
# Audio duration: 7.47
# Number of images in segment 22: 1
# Audio duration: 4.31
# Number of images in segment 23: 1
# Audio duration: 3.53
# Number of images in segment 24: 1
# Audio duration: 7.65
# Number of images in segment 25: 1
# Audio duration: 5.33
# Number of images in segment 26: 1
# Audio duration: 5.25
# Number of images in segment 27: 1
# Audio duration: 8.02
# Number of images in segment 28: 1
# Audio duration: 10.34
# Number of images in segment 29: 1
# Audio duration: 5.15
# Number of images in segment 30: 1
# Audio duration: 11.96
# Number of images in segment 31: 1
# Audio duration: 14.52
# Number of images in segment 32: 1
# Audio duration: 13.37
# Number of images in segment 33: 1
# Audio duration: 5.98
# Number of images in segment 34: 1
# Audio duration: 8.31
# Number of images in segment 35: 1
# Audio duration: 20.9
# Number of images in segment 36: 2
# Audio duration: 12.77
# Number of images in segment 37: 2
# Audio duration: 18.0
# Number of images in segment 38: 3
# Audio duration: 22.18
# Number of images in segment 39: 2
# Audio duration: 18.83
# Number of images in segment 40: 1
# Audio duration: 15.49
# Number of images in segment 41: 1
# Audio duration: 8.2
# Number of images in segment 42: 2
# Audio duration: 19.91
# Number of images in segment 43: 2
# Detecting text:   1%|          | 1/154 [4:25:59<07:27,  2.92s/it]
# Audio duration: 17.82
# Number of images in segment 44: 1
# Audio duration: 5.04
# Moviepy - Building video naruto/v10/recap.mp4.
# MoviePy - Writing audio in naruto/v10/temp-audio.m4a
# Detecting text:   1%|          | 1/154 [4:26:13<07:27,  2.92s/it]
# MoviePy - Done.
# Moviepy - Writing video naruto/v10/recap.mp4
# Detecting text:   1%|          | 1/154 [4:26:34<07:27,  2.92s/it]
# Moviepy - Done !
# Moviepy - video ready naruto/v10/recap.mp4
# Movie created successfully!
# True
